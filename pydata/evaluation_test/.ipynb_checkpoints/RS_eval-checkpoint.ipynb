# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %%
def u2i_eval_daily_summary(rec_daily, mapping_tab, rec_num):
    a = rec_daily.groupby('user_ID').apply(lambda x: x.sort_values(by='request_time')['sku_ID'].tolist())
    
    ## main part
    pred_cover_by_user = a.to_frame().apply(lambda x: pd.Series(eval_helper(mapping_tab=mapping_tab, click_list=x[0], rec_num=rec_num, user_ID=x.name)), axis=1)
    
    pred_suc, total_pred_num = pred_cover_by_user.sum(axis=0)
    pred_suc_ratio = pred_suc/total_pred_num
    return pred_suc_ratio, pred_suc, total_pred_num, pred_cover_by_user

def get_daily_formated_summary(rec_daily, ui2i_tab, tech_type, recommend_type, date):
    res_list = []
    for rec_num in range(1,10):
        if recommend_type == "user to item":
            pred_suc_ratio, pred_suc, total_pred_num, pred_cover_by_user = u2i_eval_daily_summary(rec_daily, mapping_tab=ui2i_tab, rec_num=rec_num)
        elif recommend_type == "item to item":
            pred_suc_ratio, pred_suc, total_pred_num, pred_cover_by_user = i2i_eval_daily_summary(rec_daily, mapping_tab=ui2i_tab, rec_num=rec_num)
        # print(pred_suc_ratio)
        res_list.append(["rec_num = " + str(rec_num), pred_suc_ratio])

    res_list.append(["total_click_samples", total_pred_num])
    res_list.append(["method", str(tech_type) + ' && '+ str(recommend_type)])
    daily_summary = pd.DataFrame.from_dict(dict(res_list), orient='index')
    daily_summary.columns = ['suc_ratio_on_'+str(date)]
    return daily_summary, pred_cover_by_user

# %%
import pandas as pd 

rec_daily = pd.read_csv('rec_daily.csv', index_col=0)[['sku_ID', 'user_ID', 'request_time']]
i2i_tab = pd.read_csv("i2i_tab.csv", index_col=0)
u2i_tab = pd.read_csv("u2i_tab.csv", index_col=0)
w2v_tab = pd.read_csv("w2v_tab.csv", index_col=0)

# %%
date, tech_type, recommend_type = now, "w2v based recommendation", "item to item"
# ui2i_tab = daily_routing.load_middle(date, tech_type, recommend_type)
ui2i_tab = w2v_tab.apply(lambda x: pd.Series(eval(x[0])), axis=1)
ds5, _ = get_daily_formated_summary(rec_daily, ui2i_tab, tech_type, recommend_type, date)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-bc8da509acaf> in <module>
#       1 date, tech_type, recommend_type = now, "w2v based recommendation", "item to item"
#       2 # ui2i_tab = daily_routing.load_middle(date, tech_type, recommend_type)
# ----> 3 ui2i_tab = ui2i_tab.apply(lambda x: pd.Series(eval(x[0])), axis=1)
#       4 ds5, _ = get_daily_formated_summary(rec_daily, ui2i_tab, tech_type, recommend_type, date)
#
# NameError: name 'ui2i_tab' is not defined

# %%
i2i_tab
# Out:
#                      0           1           2           3           4  \
# 00556fba9b  00556fba9b  61035415ba  aff785a666  affbda16ea  aff93b0a8c
# 00cb69d8fd  00cb69d8fd  b4841fb3f7  b68a815b97  42001e8904  7e4cb4952a
# 00e5480a1e  00e5480a1e  aff785a666  af9f2a0737  affbda16ea  aff93b0a8c
# 00ee594cec  25ff4fa3af  00ee594cec  b720d538ec  aff93b0a8c  affbda16ea
# 00ef67a0a3  00ef67a0a3  aff785a666  affbda16ea  aff93b0a8c  b09a617337
# ...                ...         ...         ...         ...         ...
# fd10ffd0a0  fd10ffd0a0  580a086465  d5eb427ced  c895dc4c68  9592abb666
# fd34a36487  fd34a36487  abc74cc224  bc1fef9128  4abbc52c37  5f413aa088
# fdeaa55518  fdeaa55518  6ba6594fcb  dacf9ea2b9  afd7ca7bbd  af0b2278bb
# fec8a56a6b  fec8a56a6b  aefceb7422  4639121a45  00f7930afa  e98fe6244e
# ff92bd94dd  39aeb30b7e  ff92bd94dd  7971a692b1  373054a9e0  f9214647cf
#
#                      5           6           7           8           9
# 00556fba9b  affc60006e  b26ce081be  afd7ca7bbd  af94cd1455  af9f2a0737
# 00cb69d8fd  1e3dc641f1  aefceb7422  c42e2a0438  861f3d422c  aff93b0a8c
# 00e5480a1e  b09a617337  b26ce081be  afd7ca7bbd  af94cd1455  affc60006e
# 00ee594cec  afd7ca7bbd  aff785a666  af9f2a0737  b0df0aa0b3  af94cd1455
# 00ef67a0a3  afd7ca7bbd  af9f2a0737  b26ce081be  af94cd1455  affc60006e
# ...                ...         ...         ...         ...         ...
# fd10ffd0a0  2bba12a78d  bb316dce76  06cad1ff9f  88a3f2a14b  e98fe6244e
# fd34a36487  7e4cb4952a  17f589d2e0  af94cd1455  af9f2a0737  afd7ca7bbd
# fdeaa55518  aff93b0a8c  af9f2a0737  aefceb7422  af94cd1455  aff785a666
# fec8a56a6b  72b8198d57  eee5d41df7  7e4cb4952a  0ad4b4a243  88a3f2a14b
# ff92bd94dd  aff93b0a8c  aff785a666  affc60006e  af9f2a0737  afd7ca7bbd
#
# [661 rows x 10 columns]

# %%
u2i_tab
# Out:
#                      0           1           2           3           4  \
# 001058d384  df66d5239a  932d4c1646  e99eb7d131  8d643cf7bf  d2b980826a
# 0019f28911  81e57cbc50  d50c683162  51da628bf9  a25b6de145  29e4f19c34
# 001a59814c  81e57cbc50  d10b8d2fba  baf3fbb0be  436e59bbcb  bc1fef9128
# 002057bd3a  7261e762c4  ab4dacb110  b5e2de2bc1  b4841fb3f7  1e98111ec9
# 002c086940  81e57cbc50  2f9e750498  067b673f2b  75cdd218b9  48c26fa27d
# ...                ...         ...         ...         ...         ...
# ffef0d2590  81e57cbc50  ac61f4e10e  b378989140  c1827caab1  c4c37a4b57
# fff084489f  81e57cbc50  ccceb52cc9  5710927122  d10b8d2fba  d0567f9df7
# fff5d94a76  81e57cbc50  aff785a666  3dd5460585  3ef4723684  b720d538ec
# fff6126d6c  81e57cbc50  d775432144  30751566fe  a887d53803  32118a2170
# fffc4db3bf  81e57cbc50  ccceb52cc9  d2b980826a  d20f9b641c  d10b8d2fba
#
#                      5           6           7           8           9
# 001058d384  d20f9b641c  d10b8d2fba  d0567f9df7  294371350c  ce96007f29
# 0019f28911  9f8c6352c1  d775432144  d92261201a  9ce99a29c2  9baa8fffc1
# 001a59814c  c4ff8911d9  38676d45f5  ccceb52cc9  35674a6b48  35333da584
# 002057bd3a  1e4d2db819  46c288b53e  af94cd1455  ac61f4e10e  48c26fa27d
# 002c086940  ac61f4e10e  61fd12c10d  89f3796b30  51da628bf9  f16794cf8a
# ...                ...         ...         ...         ...         ...
# ffef0d2590  38676d45f5  c4ff8911d9  c8ce38c12f  35674a6b48  3418d59e22
# fff084489f  29c8797899  29e4f19c34  ce15d3c844  8b930b0131  2b82f7ac49
# fff5d94a76  b4ac267fa7  436e59bbcb  43be829eb9  b378989140  443346ceab
# fff6126d6c  a8c80a32be  5f413aa088  d7c786790b  d70cd7d343  38676d45f5
# fffc4db3bf  d0567f9df7  294371350c  ce96007f29  52d7273278  29e4f19c34
#
# [8094 rows x 10 columns]

# %%
# Out:
#                                        suc_ratio_on_2018-03-14  \
# rec_num = 1                                           0.048755
# rec_num = 2                                           0.067303
# rec_num = 3                                           0.085321
# rec_num = 4                                           0.101219
# rec_num = 5                                           0.108638
# rec_num = 6                                           0.120827
# rec_num = 7                                           0.144144
# rec_num = 8                                           0.144674
# rec_num = 9                                           0.147324
# total_click_samples                                       1887
# method               item based recommendation && user to item
#
#                                        suc_ratio_on_2018-03-14
# rec_num = 1                                           0.048755
# rec_num = 2                                           0.067303
# rec_num = 3                                           0.085321
# rec_num = 4                                           0.101219
# rec_num = 5                                           0.108638
# rec_num = 6                                           0.120827
# rec_num = 7                                           0.144144
# rec_num = 8                                           0.144674
# rec_num = 9                                           0.147324
# total_click_samples                                       1887
# method               item based recommendation && user to item

# %%
def

# %%
daily_summary
# Out:
#                                        suc_ratio_on_2018-03-14
# rec_num = 1                                           0.048755
# rec_num = 2                                           0.067303
# rec_num = 3                                           0.085321
# rec_num = 4                                           0.101219
# rec_num = 5                                           0.108638
# rec_num = 6                                           0.120827
# rec_num = 7                                           0.144144
# rec_num = 8                                           0.144674
# rec_num = 9                                           0.147324
# total_click_samples                                       1887
# method               item based recommendation && user to item
